# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import duckdb

con = duckdb.connect('../data/processed/portwatch.duckdb')
df = con.execute('SELECT * FROM port_activity').df()
df.head()
